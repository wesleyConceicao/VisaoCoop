# %%
import pandas as pd
import numpy as np
import os

# %%
path = "C:\\Users\\wesle\\VisãoCoop\\03-2023"
# ---------------------------------
sympla = pd.read_excel(os.path.join(path,'NÃO MEXER. Formação Online e Presencial - Lista de Participantes.xlsx'))

# ----------------------------------------
modulo_Alfabetização_Digital = pd.read_excel(os.path.join(path,"Alfabetização Digital - Formação Criar Jogos.xlsx"))
modulo_Cultura_de_Jogos = pd.read_excel(os.path.join(path,"Cultura de Jogos - Formação Criar Jogos.xlsx"))
modulo_Roteiro_e_Narrativa = pd.read_excel(os.path.join(path,"Roteiro e Narrativa - Formação Criar Jogos.xlsx"))
modulo_Programação = pd.read_excel(os.path.join(path,"Programação - Formação Criar Jogos.xlsx"))
modulo_Edição_de_Som = pd.read_excel(os.path.join(path,"Edição de Som - Formação Criar Jogos.xlsx"))
modulo_Game_Design = pd.read_excel(os.path.join(path,"Game Design - Formação Criar Jogos.xlsx"))
modulo_Arte_e_Interface = pd.read_excel(os.path.join(path,"Arte e Interface - Formação Criar Jogos.xlsx"))
modulo_Protótipo = pd.read_excel(os.path.join(path,"Protótipo - Formação Criar Jogos.xlsx"))
modulo_Temporada_Ferias = pd.read_excel(os.path.join(path,"Temporada de Férias - Mercado de Games.xlsx"))
# ----------------------
modulo_Alfabetização_DigitalBH = pd.read_excel(os.path.join(path,"Alfabetização Digital - Polo Belo Horizonte.xlsx"))
modulo_Cultura_de_JogosBH = pd.read_excel(os.path.join(path,"Cultura de Jogos - Polo Belo Horizonte.xlsx"))
modulo_Roteiro_e_NarrativaBH = pd.read_excel(os.path.join(path,"Roteiro e Narrativa - Polo Belo Horizonte.xlsx"))

# %%
### Correção da Tabela

correcao_coluna = sympla.rename(columns=sympla.iloc[0])
alunos_inscritos_sympla_formacaoCriarJogos = correcao_coluna.drop([0, 1]).reset_index(drop=True)

################################
alunos_inscritos_sympla_formacaoCriarJogos.drop(["Data","Tipo de ingresso","Nº","Endereço","Compl.","Bairro","TEL","RG ou CPF","É indicação, filho (a) ou parente de algum dos patrocinadores do projeto?"], axis = 1, inplace = True)

# alunos_inscritos_sympla_formacaoCriarJogos = alunos_inscritos_sympla_formacaoCriarJogos.loc[dados_mentora["Role"] == "mentee"]

# %%
dados_sympla_corrigido = pd.DataFrame({
                        'Nome': alunos_inscritos_sympla_formacaoCriarJogos['Nome'] + " " +alunos_inscritos_sympla_formacaoCriarJogos['Sobrenome'].str.lower(),
                        "Email":alunos_inscritos_sympla_formacaoCriarJogos['Email'].str.lower(),
                        'Formato do curso':alunos_inscritos_sympla_formacaoCriarJogos['Formato do curso'],
                        'Polo Presencial São Gonçalo dos Campos (BA) - Biblioteca Municipal Aníbal Pedreira':alunos_inscritos_sympla_formacaoCriarJogos['Polo Presencial São Gonçalo dos Campos (BA) | Biblioteca Municipal Aníbal Pedreira'],
                        'Polo Presencial São Gonçalo dos Campos (BA) - Colégio Mun. Agripina de L Pedreira':alunos_inscritos_sympla_formacaoCriarJogos['Polo Presencial São Gonçalo dos Campos (BA) | Colégio Mun. Agripina de L Pedreira'],
                        'Polo Presencial Mogi Guaçu (SP) - CEGEP':alunos_inscritos_sympla_formacaoCriarJogos['Polo Presencial Mogi Guaçu (SP) | CEGEP'],
                        'Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro':alunos_inscritos_sympla_formacaoCriarJogos['Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro'],
                        'Polo Presencial Camaçari (BA) - UFBA':alunos_inscritos_sympla_formacaoCriarJogos['Polo Presencial Camaçari (BA) | UFBA'],
                        'Polo Presencial Camaçari (BA) - CIAT':alunos_inscritos_sympla_formacaoCriarJogos['Polo Presencial Camaçari (BA) | CIAT'],}).sort_values(by='Email')

# %%
dados_sympla_corrigido.info()

# %%
modulo_Alfabetização_Digital['Email'] = modulo_Alfabetização_Digital['Email'].str.lower()
modulo_Cultura_de_Jogos['Email'] = modulo_Cultura_de_Jogos['Email'].str.lower()
modulo_Roteiro_e_Narrativa['Email'] = modulo_Roteiro_e_Narrativa['Email'].str.lower()
modulo_Programação['Email'] = modulo_Programação['Email'].str.lower()
modulo_Edição_de_Som['Email'] = modulo_Edição_de_Som['Email'].str.lower()
modulo_Game_Design['Email'] = modulo_Game_Design['Email'].str.lower()
modulo_Arte_e_Interface['Email'] = modulo_Arte_e_Interface['Email'].str.lower()
modulo_Protótipo['Email'] = modulo_Protótipo['Email'].str.lower()
modulo_Temporada_Ferias['Email'] = modulo_Temporada_Ferias['Email'].str.lower()
#------------------------------------
modulo_Alfabetização_DigitalBH['Email'] = modulo_Alfabetização_DigitalBH['Email'].str.lower()
modulo_Cultura_de_JogosBH['Email'] = modulo_Cultura_de_JogosBH['Email'].str.lower()
modulo_Roteiro_e_NarrativaBH['Email'] = modulo_Roteiro_e_NarrativaBH['Email'].str.lower()

# %%
alunos_modulo_Alfabetização_Digital = dados_sympla_corrigido.merge(modulo_Alfabetização_Digital,how = 'right', on = 'Email')
alunos_modulo_Cultura_de_Jogos = dados_sympla_corrigido.merge(modulo_Cultura_de_Jogos,how = 'right', on = 'Email')
alunos_modulo_Roteiro_e_Narrativa = dados_sympla_corrigido.merge(modulo_Roteiro_e_Narrativa,how = 'right', on = 'Email')
alunos_modulo_Programação = dados_sympla_corrigido.merge(modulo_Programação,how = 'right', on = 'Email')
alunos_modulo_Edição_de_Som = dados_sympla_corrigido.merge(modulo_Edição_de_Som,how = 'right', on = 'Email')
alunos_modulo_Game_Design = dados_sympla_corrigido.merge(modulo_Game_Design,how = 'right', on = 'Email')
alunos_modulo_Arte_e_Interface = dados_sympla_corrigido.merge(modulo_Arte_e_Interface,how = 'right', on = 'Email')
alunos_modulo_Protótipo = dados_sympla_corrigido.merge(modulo_Protótipo,how = 'right', on = 'Email')                   
alunos_modulo_Temporada_Ferias = dados_sympla_corrigido.merge(modulo_Temporada_Ferias,how = 'right', on = 'Email')     
#-----------------------------------
alunos_modulo_Alfabetização_DigitalBH = dados_sympla_corrigido.merge(modulo_Alfabetização_DigitalBH,how = 'right', on = 'Email')
alunos_modulo_Cultura_de_JogosBH = dados_sympla_corrigido.merge(modulo_Cultura_de_JogosBH,how = 'right', on = 'Email')
alunos_modulo_Roteiro_e_NarrativaBH = dados_sympla_corrigido.merge(modulo_Roteiro_e_NarrativaBH,how = 'right', on = 'Email')

# %% [markdown]
# ### Extração Polos - Polo Presencial São Gonçalo dos Campos (BA) - Biblioteca Municipal Aníbal Pedreira

# %%
# Extração Polos - Polo Presencial São Gonçalo dos Campos (BA) - Biblioteca Municipal Aníbal Pedreira

Modulo_Alfabetizacao_Digital_Polo_Biblioteca_Municipal_Aníbal_Pedreira = pd.DataFrame({
                        'Nome':alunos_modulo_Alfabetização_Digital['Nome'],
                        'Participante': alunos_modulo_Alfabetização_Digital['Participante'],
                        "Email":alunos_modulo_Alfabetização_Digital['Email'],
                        'Pontuação': alunos_modulo_Alfabetização_Digital['Pontuação pts'].loc[alunos_modulo_Alfabetização_Digital['Pontuação pts'] >= 150],
                        'Polo Presencial São Gonçalo dos Campos (BA) - Biblioteca Municipal Aníbal Pedreira':alunos_modulo_Alfabetização_Digital['Polo Presencial São Gonçalo dos Campos (BA) - Biblioteca Municipal Aníbal Pedreira']}).sort_values(by='Email').dropna()

Modulo_Alfabetizacao_Digital_Polo_Biblioteca_Municipal_Aníbal_Pedreira.to_excel("dados_relação_Alunos_Alfabetização_Digital.xlsx", index = False)

Modulo_Cultura_de_Jogos_Polo_Biblioteca_Municipal_Aníbal_Pedreira = pd.DataFrame({
                        'Nome':alunos_modulo_Cultura_de_Jogos['Nome'],
                        'Participante': alunos_modulo_Cultura_de_Jogos['Participante'],
                        "Email":alunos_modulo_Cultura_de_Jogos['Email'],
                        'Pontuação': alunos_modulo_Cultura_de_Jogos['Pontuação pts'].loc[alunos_modulo_Cultura_de_Jogos['Pontuação pts'] >= 400],
                        'Polo Presencial São Gonçalo dos Campos (BA) - Biblioteca Municipal Aníbal Pedreira':alunos_modulo_Cultura_de_Jogos['Polo Presencial São Gonçalo dos Campos (BA) - Biblioteca Municipal Aníbal Pedreira']}).sort_values(by='Email').dropna()

Modulo_Cultura_de_Jogos_Polo_Biblioteca_Municipal_Aníbal_Pedreira.to_excel("dados_relação_Alunos_Cultura_de_Jogos.xlsx", index = False)

Modulo_Roteiro_e_Narrativa_Polo_Biblioteca_Municipal_Aníbal_Pedreira = pd.DataFrame({
                        'Nome':alunos_modulo_Roteiro_e_Narrativa['Nome'],
                        'Participante': alunos_modulo_Roteiro_e_Narrativa['Participante'],
                        "Email":alunos_modulo_Roteiro_e_Narrativa['Email'],
                        'Pontuação': alunos_modulo_Roteiro_e_Narrativa['Pontuação pts'].loc[alunos_modulo_Roteiro_e_Narrativa['Pontuação pts'] >= 500],
                        'Polo Presencial São Gonçalo dos Campos (BA) - Biblioteca Municipal Aníbal Pedreira':alunos_modulo_Roteiro_e_Narrativa['Polo Presencial São Gonçalo dos Campos (BA) - Biblioteca Municipal Aníbal Pedreira']}).sort_values(by='Email').dropna()

Modulo_Roteiro_e_Narrativa_Polo_Biblioteca_Municipal_Aníbal_Pedreira.to_excel("dados_relação_Alunos_Roteiro_e_Narrativa.xlsx", index = False)


Modulo_Programação_Polo_Biblioteca_Municipal_Aníbal_Pedreira = pd.DataFrame({
                        'Nome':alunos_modulo_Cultura_de_Jogos['Nome'],
                        'Participante': alunos_modulo_Programação['Participante'],
                        "Email":alunos_modulo_Programação['Email'],
                        'Pontuação': alunos_modulo_Programação['Pontuação pts'].loc[alunos_modulo_Programação['Pontuação pts'] >= 500],
                        'Polo Presencial São Gonçalo dos Campos (BA) - Biblioteca Municipal Aníbal Pedreira':alunos_modulo_Programação['Polo Presencial São Gonçalo dos Campos (BA) - Biblioteca Municipal Aníbal Pedreira']}).sort_values(by='Email').dropna()

Modulo_Programação_Polo_Biblioteca_Municipal_Aníbal_Pedreira.to_excel("dados_relação_Alunos_programacao.xlsx", index = False)


Modulo_Edição_de_Som_Polo_Biblioteca_Municipal_Aníbal_Pedreira = pd.DataFrame({
                        'Nome':alunos_modulo_Edição_de_Som['Nome'],
                        'Participante': alunos_modulo_Edição_de_Som['Participante'],
                        "Email":alunos_modulo_Edição_de_Som['Email'],
                        'Pontuação':alunos_modulo_Edição_de_Som['Pontuação pts'].loc[alunos_modulo_Edição_de_Som['Pontuação pts'] >= 500],
                        'Polo Presencial São Gonçalo dos Campos (BA) - Biblioteca Municipal Aníbal Pedreira':alunos_modulo_Edição_de_Som['Polo Presencial São Gonçalo dos Campos (BA) - Biblioteca Municipal Aníbal Pedreira']}).sort_values(by='Email').dropna()

Modulo_Edição_de_Som_Polo_Biblioteca_Municipal_Aníbal_Pedreira.to_excel("dados_relação_Alunos_Edição_de_Som.xlsx", index = False)

Modulo_Game_Design_Polo_Biblioteca_Municipal_Aníbal_Pedreira = pd.DataFrame({
                        'Nome':alunos_modulo_Game_Design['Nome'],
                        'Participante': alunos_modulo_Game_Design['Participante'],
                        "Email":alunos_modulo_Game_Design['Email'],
                        'Pontuação':alunos_modulo_Game_Design['Pontuação pts'].loc[alunos_modulo_Game_Design['Pontuação pts'] >= 500],
                        'Polo Presencial São Gonçalo dos Campos (BA) - Biblioteca Municipal Aníbal Pedreira':alunos_modulo_Game_Design['Polo Presencial São Gonçalo dos Campos (BA) - Biblioteca Municipal Aníbal Pedreira']}).sort_values(by='Email').dropna()

Modulo_Game_Design_Polo_Biblioteca_Municipal_Aníbal_Pedreira.to_excel("dados_relação_Alunos_gameDesign.xlsx", index = False)

Modulo_Arte_e_Interface_Polo_Biblioteca_Municipal_Aníbal_Pedreira = pd.DataFrame({
                        'Nome':alunos_modulo_Arte_e_Interface['Nome'],
                        'Participante': alunos_modulo_Arte_e_Interface['Participante'],
                        "Email":alunos_modulo_Arte_e_Interface['Email'],
                        'Pontuação':alunos_modulo_Arte_e_Interface['Pontuação pts'].loc[alunos_modulo_Arte_e_Interface['Pontuação pts'] >= 500],
                        'Polo Presencial São Gonçalo dos Campos (BA) - Biblioteca Municipal Aníbal Pedreira':alunos_modulo_Arte_e_Interface['Polo Presencial São Gonçalo dos Campos (BA) - Biblioteca Municipal Aníbal Pedreira']}).sort_values(by='Email').dropna()

Modulo_Arte_e_Interface_Polo_Biblioteca_Municipal_Aníbal_Pedreira.to_excel("dados_relação_Alunos_prototipo.xlsx", index = False)

Modulo_Protótipo_Polo_Biblioteca_Municipal_Aníbal_Pedreira = pd.DataFrame({
                        'Nome':alunos_modulo_Protótipo['Nome'],
                        'Participante': alunos_modulo_Protótipo['Participante'],
                        "Email":alunos_modulo_Protótipo['Email'],
                        'Pontuação': alunos_modulo_Protótipo['Pontuação pts'].loc[alunos_modulo_Protótipo['Pontuação pts'] >= 500],
                        'Polo Presencial São Gonçalo dos Campos (BA) - Biblioteca Municipal Aníbal Pedreira':alunos_modulo_Protótipo['Polo Presencial São Gonçalo dos Campos (BA) - Biblioteca Municipal Aníbal Pedreira']}).sort_values(by='Email').dropna()

Modulo_Protótipo_Polo_Biblioteca_Municipal_Aníbal_Pedreira.to_excel("dados_relação_Alunos_Arte_e_Interface.xlsx", index = False)

Modulo_Temporada_Ferias_Polo_Biblioteca_Municipal_Aníbal_Pedreira = pd.DataFrame({
                        'Nome':alunos_modulo_Temporada_Ferias['Nome'],
                        'Participante': alunos_modulo_Temporada_Ferias['Participante'],
                        "Email":alunos_modulo_Temporada_Ferias['Email'],
                        'Pontuação': alunos_modulo_Temporada_Ferias['Pontuação pts'].loc[alunos_modulo_Temporada_Ferias['Pontuação pts'] >= 1500],
                        'Polo Presencial São Gonçalo dos Campos (BA) - Biblioteca Municipal Aníbal Pedreira':alunos_modulo_Temporada_Ferias['Polo Presencial São Gonçalo dos Campos (BA) - Biblioteca Municipal Aníbal Pedreira']}).sort_values(by='Email').dropna()

Modulo_Temporada_Ferias_Polo_Biblioteca_Municipal_Aníbal_Pedreira.to_excel("dados_relação_Aluno_Temporada_Ferias.xlsx", index = False)

# %%
Modulo_Alfabetizacao_Digital_Polo_Biblioteca_Municipal_Aníbal_Pedreira.info()

# %% [markdown]
# ### Extração Polos - Polo Presencial São Gonçalo dos Campos (BA) - Colégio Mun. Agripina de L Pedreira

# %%
# Extração Polos - Polo Presencial São Gonçalo dos Campos (BA) - Colégio Mun. Agripina de L Pedreira

Modulo_Alfabetizacao_Digital_Polo_Colégio_Mun_Agripina_de_L_Pedreira = pd.DataFrame({
                        'Nome':alunos_modulo_Alfabetização_Digital['Nome'],
                        'Participante': alunos_modulo_Alfabetização_Digital['Participante'],
                        "Email":alunos_modulo_Alfabetização_Digital['Email'],
                        'Pontuação': alunos_modulo_Alfabetização_Digital['Pontuação pts'].loc[alunos_modulo_Alfabetização_Digital['Pontuação pts'] >= 150],
                        'Polo Presencial São Gonçalo dos Campos (BA) - Colégio Mun. Agripina de L Pedreira':alunos_modulo_Alfabetização_Digital['Polo Presencial São Gonçalo dos Campos (BA) - Colégio Mun. Agripina de L Pedreira']}).sort_values(by='Email').dropna()

Modulo_Alfabetizacao_Digital_Polo_Colégio_Mun_Agripina_de_L_Pedreira.to_excel("dados_relação_Alunos_Alfabetização_Digital.xlsx", index = False)

Modulo_Cultura_de_Jogos_Polo_Colégio_Mun_Agripina_de_L_Pedreira = pd.DataFrame({
                        'Nome':alunos_modulo_Cultura_de_Jogos['Nome'],
                        'Participante': alunos_modulo_Cultura_de_Jogos['Participante'],
                        "Email":alunos_modulo_Cultura_de_Jogos['Email'],
                        'Pontuação': alunos_modulo_Cultura_de_Jogos['Pontuação pts'].loc[alunos_modulo_Cultura_de_Jogos['Pontuação pts'] >= 400],
                        'Polo Presencial São Gonçalo dos Campos (BA) - Colégio Mun. Agripina de L Pedreira':alunos_modulo_Cultura_de_Jogos['Polo Presencial São Gonçalo dos Campos (BA) - Colégio Mun. Agripina de L Pedreira']}).sort_values(by='Email').dropna()
Modulo_Cultura_de_Jogos_Polo_Colégio_Mun_Agripina_de_L_Pedreira.to_excel("dados_relação_Alunos_Cultura_de_Jogos.xlsx", index = False)

Modulo_Roteiro_e_Narrativa_Polo_Colégio_Mun_Agripina_de_L_Pedreira = pd.DataFrame({
                        'Nome':alunos_modulo_Roteiro_e_Narrativa['Nome'],
                        'Participante': alunos_modulo_Roteiro_e_Narrativa['Participante'],
                        "Email":alunos_modulo_Roteiro_e_Narrativa['Email'],
                        'Pontuação': alunos_modulo_Roteiro_e_Narrativa['Pontuação pts'].loc[alunos_modulo_Roteiro_e_Narrativa['Pontuação pts'] >= 500],
                        'Polo Presencial São Gonçalo dos Campos (BA) - Colégio Mun. Agripina de L Pedreira':alunos_modulo_Roteiro_e_Narrativa['Polo Presencial São Gonçalo dos Campos (BA) - Colégio Mun. Agripina de L Pedreira']}).sort_values(by='Email').dropna()
Modulo_Roteiro_e_Narrativa_Polo_Colégio_Mun_Agripina_de_L_Pedreira.to_excel("dados_relação_Alunos_Roteiro_e_Narrativa.xlsx", index = False)


Modulo_Programação_Polo_Colégio_Mun_Agripina_de_L_Pedreira = pd.DataFrame({
                        'Nome':alunos_modulo_Programação['Nome'],
                        'Participante': alunos_modulo_Programação['Participante'],
                        "Email":alunos_modulo_Programação['Email'],
                        'Pontuação': alunos_modulo_Programação['Pontuação pts'].loc[alunos_modulo_Programação['Pontuação pts'] >= 500],
                        'Polo Presencial São Gonçalo dos Campos (BA) - Colégio Mun. Agripina de L Pedreira':alunos_modulo_Programação['Polo Presencial São Gonçalo dos Campos (BA) - Colégio Mun. Agripina de L Pedreira']}).sort_values(by='Email').dropna()
Modulo_Programação_Polo_Colégio_Mun_Agripina_de_L_Pedreira.to_excel("dados_relação_Alunos_programacao.xlsx", index = False)

Modulo_Edição_de_Som_Polo_Colégio_Mun_Agripina_de_L_Pedreira = pd.DataFrame({
                        'Nome':alunos_modulo_Edição_de_Som['Nome'],
                        'Participante': alunos_modulo_Edição_de_Som['Participante'],
                        "Email":alunos_modulo_Edição_de_Som['Email'],
                        'Pontuação': alunos_modulo_Edição_de_Som['Pontuação pts'].loc[alunos_modulo_Edição_de_Som['Pontuação pts'] >= 500],
                        'Polo Presencial São Gonçalo dos Campos (BA) - Colégio Mun. Agripina de L Pedreira':alunos_modulo_Edição_de_Som['Polo Presencial São Gonçalo dos Campos (BA) - Colégio Mun. Agripina de L Pedreira']}).sort_values(by='Email').dropna()
Modulo_Edição_de_Som_Polo_Colégio_Mun_Agripina_de_L_Pedreira.to_excel("dados_relação_Alunos_Edição_de_Som.xlsx", index = False)

Modulo_Game_Design_Polo_Colégio_Mun_Agripina_de_L_Pedreira = pd.DataFrame({
                        'Nome': alunos_modulo_Game_Design['Nome'],
                        'Participante': alunos_modulo_Game_Design['Participante'],
                        "Email":alunos_modulo_Game_Design['Email'],
                        'Pontuação': alunos_modulo_Game_Design['Pontuação pts'].loc[alunos_modulo_Game_Design['Pontuação pts'] >= 500],
                        'Polo Presencial São Gonçalo dos Campos (BA) - Colégio Mun. Agripina de L Pedreira':alunos_modulo_Game_Design['Polo Presencial São Gonçalo dos Campos (BA) - Colégio Mun. Agripina de L Pedreira']}).sort_values(by='Email').dropna()
Modulo_Game_Design_Polo_Colégio_Mun_Agripina_de_L_Pedreira.to_excel("dados_relação_Alunos_gameDesign.xlsx", index = False)

Modulo_Arte_e_Interface_Polo_Colégio_Mun_Agripina_de_L_Pedreira = pd.DataFrame({
                        'Nome':alunos_modulo_Arte_e_Interface['Nome'],
                        'Participante': alunos_modulo_Arte_e_Interface['Participante'],
                        "Email":alunos_modulo_Arte_e_Interface['Email'],
                        'Pontuação': alunos_modulo_Arte_e_Interface['Pontuação pts'].loc[alunos_modulo_Arte_e_Interface['Pontuação pts'] >= 500],
                        'Polo Presencial São Gonçalo dos Campos (BA) - Colégio Mun. Agripina de L Pedreira':alunos_modulo_Arte_e_Interface['Polo Presencial São Gonçalo dos Campos (BA) - Colégio Mun. Agripina de L Pedreira']}).sort_values(by='Email').dropna()
Modulo_Arte_e_Interface_Polo_Colégio_Mun_Agripina_de_L_Pedreira.to_excel("dados_relação_Alunos_Arte_e_Interface.xlsx", index = False)

Modulo_Protótipo_Polo_Colégio_Mun_Agripina_de_L_Pedreira = pd.DataFrame({
                        'Nome':alunos_modulo_Protótipo['Nome'],
                        'Participante': alunos_modulo_Protótipo['Participante'],
                        "Email":alunos_modulo_Protótipo['Email'],
                        'Pontuação': alunos_modulo_Cultura_de_Jogos['Pontuação pts'].loc[alunos_modulo_Cultura_de_Jogos['Pontuação pts'] >= 500],
                        'Polo Presencial São Gonçalo dos Campos (BA) - Colégio Mun. Agripina de L Pedreira':alunos_modulo_Protótipo['Polo Presencial São Gonçalo dos Campos (BA) - Colégio Mun. Agripina de L Pedreira']}).sort_values(by='Email').dropna()
Modulo_Protótipo_Polo_Colégio_Mun_Agripina_de_L_Pedreira.to_excel("dados_relação_Alunos_prototipo.xlsx", index = False)

Modulo_Temporada_Ferias_Polo_Colégio_Mun_Agripina_de_L_Pedreira = pd.DataFrame({
                        'Nome': alunos_modulo_Temporada_Ferias['Participante'],
                        "Email":alunos_modulo_Temporada_Ferias['Email'],
                        'Pontuação': alunos_modulo_Temporada_Ferias['Pontuação pts'].loc[alunos_modulo_Temporada_Ferias['Pontuação pts'] >= 1500],
                        'Polo Presencial São Gonçalo dos Campos (BA) - Colégio Mun. Agripina de L Pedreira':alunos_modulo_Temporada_Ferias['Polo Presencial São Gonçalo dos Campos (BA) - Colégio Mun. Agripina de L Pedreira']}).sort_values(by='Email').dropna()
Modulo_Temporada_Ferias_Polo_Colégio_Mun_Agripina_de_L_Pedreira.to_excel("dados_relação_Aluno_Temporada_Ferias.xlsx", index = False)

# %% [markdown]
# ### Polo Presencial Camaçari (BA) - UFBA

# %%
# Extração Polos - Polo Presencial Camaçari (BA) - UFBA 
Modulo_Alfabetizacao_Digital_Polo_Presencial_Camaçari_UFBA = pd.DataFrame({
                        'Nome':alunos_modulo_Alfabetização_Digital['Nome'],
                        'Participante': alunos_modulo_Alfabetização_Digital['Participante'],
                        "Email":alunos_modulo_Alfabetização_Digital['Email'],
                        'Pontuação': alunos_modulo_Alfabetização_Digital['Pontuação pts'].loc[alunos_modulo_Alfabetização_Digital['Pontuação pts'] >= 150],
                        'Polo Presencial Camaçari (BA) - UFBA':alunos_modulo_Alfabetização_Digital['Polo Presencial Camaçari (BA) - UFBA']}).sort_values(by='Email').dropna()

Modulo_Alfabetizacao_Digital_Polo_Presencial_Camaçari_UFBA.to_excel("dados_relação_Alunos_Alfabetização_Digital.xlsx", index = False)

Modulo_Cultura_de_Jogos_Polo_Presencial_Camaçari_UFBA = pd.DataFrame({
                        'Nome':alunos_modulo_Cultura_de_Jogos['Nome'],
                        'Participante': alunos_modulo_Cultura_de_Jogos['Participante'],
                        "Email":alunos_modulo_Cultura_de_Jogos['Email'],
                        'Pontuação': alunos_modulo_Cultura_de_Jogos['Pontuação pts'].loc[alunos_modulo_Cultura_de_Jogos['Pontuação pts'] >= 400],
                        'Polo Presencial Camaçari (BA) - UFBA':alunos_modulo_Cultura_de_Jogos['Polo Presencial Camaçari (BA) - UFBA']}).sort_values(by='Email').dropna()
Modulo_Cultura_de_Jogos_Polo_Presencial_Camaçari_UFBA.to_excel("dados_relação_Alunos_Cultura_de_Jogos.xlsx", index = False)

Modulo_Roteiro_e_Narrativa_Polo_Presencial_Camaçari_UFBA = pd.DataFrame({
                        'Nome':alunos_modulo_Roteiro_e_Narrativa['Nome'],
                        'Participante': alunos_modulo_Roteiro_e_Narrativa['Participante'],
                        "Email":alunos_modulo_Roteiro_e_Narrativa['Email'],
                        'Pontuação': alunos_modulo_Roteiro_e_Narrativa['Pontuação pts'].loc[alunos_modulo_Roteiro_e_Narrativa['Pontuação pts'] >= 500],
                        'Polo Presencial Camaçari (BA) - UFBA':alunos_modulo_Roteiro_e_Narrativa['Polo Presencial Camaçari (BA) - UFBA']}).sort_values(by='Email').dropna()
Modulo_Roteiro_e_Narrativa_Polo_Presencial_Camaçari_UFBA.to_excel("dados_relação_Alunos_Roteiro_e_Narrativa.xlsx", index = False)

Modulo_Programação_Polo_Presencial_Camaçari_UFBA = pd.DataFrame({
                        'Nome':alunos_modulo_Programação['Nome'],
                        'Participante': alunos_modulo_Programação['Participante'],
                        "Email":alunos_modulo_Programação['Email'],
                        'Pontuação': alunos_modulo_Programação['Pontuação pts'].loc[alunos_modulo_Programação['Pontuação pts'] >= 500],
                        'Polo Presencial Camaçari (BA) - UFBA':alunos_modulo_Programação['Polo Presencial Camaçari (BA) - UFBA']}).sort_values(by='Email').dropna()
Modulo_Programação_Polo_Presencial_Camaçari_UFBA.to_excel("dados_relação_Alunos_programacao.xlsx", index = False)

Modulo_Edição_de_Som_Polo_Presencial_Camaçari_UFBA = pd.DataFrame({
                        'Nome':alunos_modulo_Edição_de_Som['Nome'],
                        'Participante': alunos_modulo_Edição_de_Som['Participante'],
                        "Email":alunos_modulo_Edição_de_Som['Email'],
                        'Pontuação': alunos_modulo_Edição_de_Som['Pontuação pts'].loc[alunos_modulo_Edição_de_Som['Pontuação pts'] >= 500],
                        'Polo Presencial Camaçari (BA) - UFBA':alunos_modulo_Edição_de_Som['Polo Presencial Camaçari (BA) - UFBA']}).sort_values(by='Email').dropna()
Modulo_Edição_de_Som_Polo_Presencial_Camaçari_UFBA.to_excel("dados_relação_Alunos_Edição_de_Som.xlsx", index = False)

Modulo_Game_Design_Polo_Presencial_Camaçari_UFBA = pd.DataFrame({
                        'Nome':alunos_modulo_Game_Design['Nome'],
                        'Participante': alunos_modulo_Game_Design['Participante'],
                        "Email":alunos_modulo_Game_Design['Email'],
                        'Pontuação': alunos_modulo_Edição_de_Som['Pontuação pts'].loc[alunos_modulo_Edição_de_Som['Pontuação pts'] >= 500],
                        'Polo Presencial Camaçari (BA) - UFBA':alunos_modulo_Game_Design['Polo Presencial Camaçari (BA) - UFBA']}).sort_values(by='Email').dropna()
Modulo_Game_Design_Polo_Presencial_Camaçari_UFBA.to_excel("dados_relação_Alunos_gameDesign.xlsx", index = False)

Modulo_Arte_e_Interface_Polo_Presencial_Camaçari_UFBA = pd.DataFrame({
                        'Nome':alunos_modulo_Arte_e_Interface['Nome'],
                        'Participante': alunos_modulo_Arte_e_Interface['Participante'],
                        "Email":alunos_modulo_Arte_e_Interface['Email'],
                        'Pontuação': alunos_modulo_Arte_e_Interface['Pontuação pts'].loc[alunos_modulo_Arte_e_Interface['Pontuação pts'] >= 500],
                        'Polo Presencial Camaçari (BA) - UFBA':alunos_modulo_Arte_e_Interface['Polo Presencial Camaçari (BA) - UFBA']}).sort_values(by='Email').dropna()
Modulo_Arte_e_Interface_Polo_Presencial_Camaçari_UFBA.to_excel("dados_relação_Alunos_Arte_e_Interface.xlsx", index = False)

Modulo_Protótipo_Polo_Presencial_Camaçari_UFBA = pd.DataFrame({
                        'Nome':alunos_modulo_Protótipo['Nome'],
                        'Participante': alunos_modulo_Protótipo['Participante'],
                        "Email":alunos_modulo_Protótipo['Email'],
                        'Pontuação': alunos_modulo_Protótipo['Pontuação pts'].loc[alunos_modulo_Protótipo['Pontuação pts'] >= 500],
                        'Polo Presencial Camaçari (BA) - UFBA':alunos_modulo_Protótipo['Polo Presencial Camaçari (BA) - UFBA']}).sort_values(by='Email').dropna()
Modulo_Protótipo_Polo_Presencial_Camaçari_UFBA.to_excel("dados_relação_Alunos_prototipo.xlsx", index = False)

Modulo_Temporada_Ferias_Polo_Presencial_Camaçari_UFBA = pd.DataFrame({
                        'Nome':alunos_modulo_Temporada_Ferias['Nome'],
                        'Participante': alunos_modulo_Temporada_Ferias['Participante'],
                        "Email":alunos_modulo_Temporada_Ferias['Email'],
                        'Pontuação': alunos_modulo_Temporada_Ferias['Pontuação pts'].loc[alunos_modulo_Temporada_Ferias['Pontuação pts'] >= 1500],
                        'Polo Presencial Camaçari (BA) - UFBA':alunos_modulo_Temporada_Ferias['Polo Presencial Camaçari (BA) - UFBA']}).sort_values(by='Email').dropna()
Modulo_Temporada_Ferias_Polo_Presencial_Camaçari_UFBA.to_excel("dados_relação_Aluno_Temporada_Ferias.xlsx", index = False)

# %% [markdown]
# ### Polo Presencial Camaçari (BA) - CIAT

# %%
# Extração Polos - Polo Presencial Camaçari (BA) - CIAT
Modulo_Alfabetizacao_Digital_Polo_Presencial_Camaçari_CIAT = pd.DataFrame({
                        'Nome':alunos_modulo_Alfabetização_Digital['Nome'],
                        'Participante': alunos_modulo_Alfabetização_Digital['Participante'],
                        "Email":alunos_modulo_Alfabetização_Digital['Email'],
                        'Pontuação': alunos_modulo_Alfabetização_Digital['Pontuação pts'].loc[alunos_modulo_Alfabetização_Digital['Pontuação pts'] >= 150],
                        'Polo Presencial Camaçari (BA) - CIAT':alunos_modulo_Alfabetização_Digital['Polo Presencial Camaçari (BA) - CIAT']}).sort_values(by='Email').dropna()
Modulo_Alfabetizacao_Digital_Polo_Presencial_Camaçari_CIAT.to_excel("dados_relação_Alunos_Alfabetização_Digital.xlsx", index = False)

Modulo_Cultura_de_Jogos_Polo_Presencial_Camaçari_CIAT = pd.DataFrame({
                        'Participante': alunos_modulo_Cultura_de_Jogos['Participante'],
                        "Email":alunos_modulo_Cultura_de_Jogos['Email'],
                        'Pontuação': alunos_modulo_Cultura_de_Jogos['Pontuação pts'].loc[alunos_modulo_Cultura_de_Jogos['Pontuação pts'] >= 400],
                        'Polo Presencial Camaçari (BA) - CIAT':alunos_modulo_Cultura_de_Jogos['Polo Presencial Camaçari (BA) - CIAT']}).sort_values(by='Email').dropna()
Modulo_Cultura_de_Jogos_Polo_Presencial_Camaçari_CIAT.to_excel("dados_relação_Alunos_Cultura_de_Jogos.xlsx", index = False)

Modulo_Roteiro_e_Narrativa_Polo_Presencial_Camaçari_CIAT = pd.DataFrame({
                        'Participante': alunos_modulo_Roteiro_e_Narrativa['Participante'],
                        "Email":alunos_modulo_Roteiro_e_Narrativa['Email'],
                        'Pontuação': alunos_modulo_Roteiro_e_Narrativa['Pontuação pts'].loc[alunos_modulo_Roteiro_e_Narrativa['Pontuação pts'] >= 500],
                        'Polo Presencial Camaçari (BA) - CIAT':alunos_modulo_Roteiro_e_Narrativa['Polo Presencial Camaçari (BA) - CIAT']}).sort_values(by='Email').dropna()
Modulo_Roteiro_e_Narrativa_Polo_Presencial_Camaçari_CIAT.to_excel("dados_relação_Alunos_Roteiro_e_Narrativa.xlsx", index = False)

Modulo_Programação_Polo_Presencial_Camaçari_CIAT = pd.DataFrame({
                        'Participante': alunos_modulo_Programação['Participante'],
                        "Email":alunos_modulo_Programação['Email'],
                        'Pontuação': alunos_modulo_Programação['Pontuação pts'].loc[alunos_modulo_Programação['Pontuação pts'] >= 500],
                        'Polo Presencial Camaçari (BA) - CIAT':alunos_modulo_Programação['Polo Presencial Camaçari (BA) - CIAT']}).sort_values(by='Email').dropna()
Modulo_Programação_Polo_Presencial_Camaçari_CIAT.to_excel("dados_relação_Alunos_programacao.xlsx", index = False)

Modulo_Edição_de_Som_Polo_Presencial_Camaçari_CIAT = pd.DataFrame({
                        'Participante': alunos_modulo_Edição_de_Som['Participante'],
                        "Email":alunos_modulo_Edição_de_Som['Email'],
                        'Pontuação': alunos_modulo_Roteiro_e_Narrativa['Pontuação pts'].loc[alunos_modulo_Roteiro_e_Narrativa['Pontuação pts'] >= 500],
                        'Polo Presencial Camaçari (BA) - CIAT':alunos_modulo_Edição_de_Som['Polo Presencial Camaçari (BA) - CIAT']}).sort_values(by='Email').dropna()
Modulo_Edição_de_Som_Polo_Presencial_Camaçari_CIAT.to_excel("dados_relação_Alunos_Edição_de_Som.xlsx", index = False)

Modulo_Game_Design_Polo_Presencial_Camaçari_CIAT = pd.DataFrame({
                        'Participante': alunos_modulo_Game_Design['Participante'],
                        "Email":alunos_modulo_Game_Design['Email'],
                        'Pontuação': alunos_modulo_Game_Design['Pontuação pts'].loc[alunos_modulo_Game_Design['Pontuação pts'] >= 500],
                        'Polo Presencial Camaçari (BA) - CIAT':alunos_modulo_Game_Design['Polo Presencial Camaçari (BA) - CIAT']}).sort_values(by='Email').dropna()
Modulo_Game_Design_Polo_Presencial_Camaçari_CIAT.to_excel("dados_relação_Alunos_gameDesign.xlsx", index = False)

Modulo_Arte_e_Interface_Polo_Presencial_Camaçari_CIAT = pd.DataFrame({
                        'Participante': alunos_modulo_Arte_e_Interface['Participante'],
                        "Email":alunos_modulo_Arte_e_Interface['Email'],
                        'Pontuação': alunos_modulo_Arte_e_Interface['Pontuação pts'].loc[alunos_modulo_Arte_e_Interface['Pontuação pts'] >= 500],
                        'Polo Presencial Camaçari (BA) - CIAT':alunos_modulo_Arte_e_Interface['Polo Presencial Camaçari (BA) - CIAT']}).sort_values(by='Email').dropna()
Modulo_Arte_e_Interface_Polo_Presencial_Camaçari_CIAT.to_excel("dados_relação_Alunos_Arte_e_Interface.xlsx", index = False)

Modulo_Protótipo_Polo_Presencial_Camaçari_CIAT = pd.DataFrame({
                        'Participante': alunos_modulo_Protótipo['Participante'],
                        "Email":alunos_modulo_Protótipo['Email'],
                        'Pontuação': alunos_modulo_Protótipo['Pontuação pts'].loc[alunos_modulo_Protótipo['Pontuação pts'] >= 500],
                        'Polo Presencial Camaçari (BA) - CIAT':alunos_modulo_Protótipo['Polo Presencial Camaçari (BA) - CIAT']}).sort_values(by='Email').dropna()
Modulo_Protótipo_Polo_Presencial_Camaçari_CIAT.to_excel("dados_relação_Alunos_prototipo.xlsx", index = False)

Modulo_Temporada_Ferias_Polo_Presencial_Camaçari_CIAT = pd.DataFrame({
                        'Participante': alunos_modulo_Temporada_Ferias['Participante'],
                        "Email":alunos_modulo_Temporada_Ferias['Email'],
                        'Pontuação': alunos_modulo_Temporada_Ferias['Pontuação pts'].loc[alunos_modulo_Temporada_Ferias['Pontuação pts'] >= 1500],
                        'Polo Presencial Camaçari (BA) - CIAT':alunos_modulo_Temporada_Ferias['Polo Presencial Camaçari (BA) - CIAT']}).sort_values(by='Email').dropna()
Modulo_Temporada_Ferias_Polo_Presencial_Camaçari_CIAT.to_excel("dados_relação_Aluno_Temporada_Ferias.xlsx", index = False)

# %% [markdown]
# ## Polo Presencial Mogi Guaçu (SP) - CEGEP

# %%
# Extração Polos - Polo Presencial Mogi Guaçu (SP) - CEGEP
Modulo_Alfabetizacao_Digital_Polo_Mogi_Guaçu_CEGEP = pd.DataFrame({
                        'Nome':alunos_modulo_Alfabetização_Digital['Nome'],
                        'Participante': alunos_modulo_Alfabetização_Digital['Participante'],
                        "Email":alunos_modulo_Alfabetização_Digital['Email'],
                        'Pontuação': alunos_modulo_Alfabetização_Digital['Pontuação pts'].loc[alunos_modulo_Alfabetização_Digital['Pontuação pts'] >= 150],
                        'Polo Presencial Mogi Guaçu (SP) - CEGEP':alunos_modulo_Alfabetização_Digital['Polo Presencial Mogi Guaçu (SP) - CEGEP']}).sort_values(by='Email').dropna()

Modulo_Alfabetizacao_Digital_Polo_Mogi_Guaçu_CEGEP.to_excel("dados_relação_Alunos_Alfabetização_Digital.xlsx", index = False)

Modulo_Cultura_de_Jogos_Polo_Mogi_Guaçu_CEGEP = pd.DataFrame({
                        'Nome':alunos_modulo_Cultura_de_Jogos['Nome'],
                        'Participante': alunos_modulo_Cultura_de_Jogos['Participante'],
                        "Email":alunos_modulo_Cultura_de_Jogos['Email'],
                        'Pontuação': alunos_modulo_Cultura_de_Jogos['Pontuação pts'].loc[alunos_modulo_Cultura_de_Jogos['Pontuação pts'] >= 400],
                        'Polo Presencial Mogi Guaçu (SP) - CEGEP':alunos_modulo_Cultura_de_Jogos['Polo Presencial Mogi Guaçu (SP) - CEGEP']}).sort_values(by='Email').dropna()
Modulo_Cultura_de_Jogos_Polo_Mogi_Guaçu_CEGEP.to_excel("dados_relação_Alunos_Cultura_de_Jogos.xlsx", index = False)

Modulo_Roteiro_e_Narrativa_Polo_Mogi_Guaçu_CEGEP= pd.DataFrame({
                        'Nome':alunos_modulo_Roteiro_e_Narrativa['Nome'],
                        'Participante': alunos_modulo_Roteiro_e_Narrativa['Participante'],
                        "Email":alunos_modulo_Roteiro_e_Narrativa['Email'],
                        'Pontuação': alunos_modulo_Roteiro_e_Narrativa['Pontuação pts'].loc[alunos_modulo_Roteiro_e_Narrativa['Pontuação pts'] >= 500],
                        'Polo Presencial Mogi Guaçu (SP) - CEGEP':alunos_modulo_Roteiro_e_Narrativa['Polo Presencial Mogi Guaçu (SP) - CEGEP']}).sort_values(by='Email').dropna()
Modulo_Roteiro_e_Narrativa_Polo_Mogi_Guaçu_CEGEP.to_excel("dados_relação_Alunos_Roteiro_e_Narrativa.xlsx", index = False)

Modulo_Programação_Polo_Mogi_Guaçu_CEGEP = pd.DataFrame({
                        'Nome':alunos_modulo_Programação['Nome'],
                        'Participante': alunos_modulo_Programação['Participante'],
                        "Email":alunos_modulo_Programação['Email'],
                        'Pontuação': alunos_modulo_Programação['Pontuação pts'].loc[alunos_modulo_Programação['Pontuação pts'] >= 500],
                        'Polo Presencial Mogi Guaçu (SP) - CEGEP':alunos_modulo_Programação['Polo Presencial Mogi Guaçu (SP) - CEGEP']}).sort_values(by='Email').dropna()
Modulo_Programação_Polo_Mogi_Guaçu_CEGEP.to_excel("dados_relação_Alunos_programacao.xlsx", index = False)

Modulo_Edição_de_Som_Polo_Mogi_Guaçu_CEGEP = pd.DataFrame({
                        'Nome':alunos_modulo_Edição_de_Som['Nome'],
                        'Participante': alunos_modulo_Edição_de_Som['Participante'],
                        "Email":alunos_modulo_Edição_de_Som['Email'],
                        'Pontuação': alunos_modulo_Edição_de_Som['Pontuação pts'].loc[alunos_modulo_Edição_de_Som['Pontuação pts'] >= 500],
                        'Polo Presencial Mogi Guaçu (SP) - CEGEP':alunos_modulo_Edição_de_Som['Polo Presencial Mogi Guaçu (SP) - CEGEP']}).sort_values(by='Email').dropna()
Modulo_Edição_de_Som_Polo_Mogi_Guaçu_CEGEP.to_excel("dados_relação_Alunos_Edição_de_Som.xlsx", index = False)

Modulo_Game_Design_Polo_Mogi_Guaçu_CEGEP = pd.DataFrame({
                        'Nome':alunos_modulo_Game_Design['Nome'],
                        'Participante': alunos_modulo_Game_Design['Participante'],
                        "Email":alunos_modulo_Game_Design['Email'],
                        'Pontuação': alunos_modulo_Game_Design['Pontuação pts'].loc[alunos_modulo_Game_Design['Pontuação pts'] >= 500],
                        'Polo Presencial Mogi Guaçu (SP) - CEGEP':alunos_modulo_Game_Design['Polo Presencial Mogi Guaçu (SP) - CEGEP']}).sort_values(by='Email').dropna()
Modulo_Game_Design_Polo_Mogi_Guaçu_CEGEP.to_excel("dados_relação_Alunos_gameDesign.xlsx", index = False)

Modulo_Arte_e_Interface_Polo_Mogi_Guaçu_CEGEP = pd.DataFrame({
                        'Nome':alunos_modulo_Arte_e_Interface['Nome'],
                        'Participante': alunos_modulo_Arte_e_Interface['Participante'],
                        "Email":alunos_modulo_Arte_e_Interface['Email'],
                        'Pontuação': alunos_modulo_Arte_e_Interface['Pontuação pts'].loc[alunos_modulo_Arte_e_Interface['Pontuação pts'] >= 500],
                        'Polo Presencial Mogi Guaçu (SP) - CEGEP':alunos_modulo_Arte_e_Interface['Polo Presencial Mogi Guaçu (SP) - CEGEP']}).sort_values(by='Email').dropna()
Modulo_Arte_e_Interface_Polo_Mogi_Guaçu_CEGEP.to_excel("dados_relação_Alunos_Arte_e_Interface.xlsx", index = False)

Modulo_Protótipo_Polo_Mogi_Guaçu_CEGEP = pd.DataFrame({
                        'Nome':alunos_modulo_Protótipo['Nome'],
                        'Participante': alunos_modulo_Protótipo['Participante'],
                        "Email":alunos_modulo_Protótipo['Email'],
                        'Pontuação': alunos_modulo_Protótipo['Pontuação pts'].loc[alunos_modulo_Protótipo['Pontuação pts'] >= 500],
                        'Polo Presencial Mogi Guaçu (SP) - CEGEP':alunos_modulo_Protótipo['Polo Presencial Mogi Guaçu (SP) - CEGEP']}).sort_values(by='Email').dropna()
Modulo_Protótipo_Polo_Mogi_Guaçu_CEGEP.to_excel("dados_relação_Alunos_prototipo.xlsx", index = False)

Modulo_Temporada_Ferias_Polo_Mogi_Guaçu_CEGEP = pd.DataFrame({
                        'Nome':alunos_modulo_Temporada_Ferias['Nome'],
                        'Participante': alunos_modulo_Temporada_Ferias['Participante'],
                        "Email":alunos_modulo_Temporada_Ferias['Email'],
                        'Pontuação': alunos_modulo_Temporada_Ferias['Pontuação pts'].loc[alunos_modulo_Temporada_Ferias['Pontuação pts'] >= 1500],
                        'Polo Presencial Mogi Guaçu (SP) - CEGEP':alunos_modulo_Temporada_Ferias['Polo Presencial Mogi Guaçu (SP) - CEGEP']}).sort_values(by='Email').dropna()
Modulo_Temporada_Ferias_Polo_Mogi_Guaçu_CEGEP.to_excel("dados_relação_Aluno_Temporada_Ferias.xlsx", index = False)

# %% [markdown]
# ### Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro

# %%
# Extração Polos - Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro
Modulo_Alfabetizacao_Digital_Polo_Belo_Horizonte_Instituto_BH_Futuro = pd.DataFrame({
                        'Nome':alunos_modulo_Alfabetização_DigitalBH['Nome'],
                        'Participante': alunos_modulo_Alfabetização_DigitalBH['Participante'],
                        "Email":alunos_modulo_Alfabetização_DigitalBH['Email'],
                        'Pontuação': alunos_modulo_Alfabetização_DigitalBH['Pontuação pts'].loc[alunos_modulo_Alfabetização_DigitalBH['Pontuação pts'] >= 150],
                        'Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro':alunos_modulo_Alfabetização_DigitalBH['Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro']}).sort_values(by='Email').dropna()
Modulo_Alfabetizacao_Digital_Polo_Belo_Horizonte_Instituto_BH_Futuro.to_excel("dados_relação_Alunos_Alfabetização_Digital.xlsx", index = False)

Modulo_Cultura_de_Jogos_Polo_Belo_Horizonte_Instituto_BH_Futuro = pd.DataFrame({
                        'Participante': alunos_modulo_Cultura_de_JogosBH['Participante'],
                        "Email":alunos_modulo_Cultura_de_JogosBH['Email'],
                        'Pontuação': alunos_modulo_Cultura_de_JogosBH['Pontuação pts'].loc[alunos_modulo_Alfabetização_DigitalBH['Pontuação pts'] >= 400],
                        'Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro':alunos_modulo_Cultura_de_JogosBH['Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro']}).sort_values(by='Email').dropna()
Modulo_Cultura_de_Jogos_Polo_Belo_Horizonte_Instituto_BH_Futuro.to_excel("dados_relação_Alunos_Cultura_de_Jogos.xlsx", index = False)

Modulo_Roteiro_e_Narrativa_Polo_Belo_Horizonte_Instituto_BH_Futuro = pd.DataFrame({
                        'Participante': alunos_modulo_Roteiro_e_NarrativaBH['Participante'],
                        "Email":alunos_modulo_Roteiro_e_NarrativaBH['Email'],
                        'Pontuação': alunos_modulo_Roteiro_e_NarrativaBH['Pontuação pts'].loc[alunos_modulo_Roteiro_e_NarrativaBH['Pontuação pts'] >= 500],
                        'Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro':alunos_modulo_Roteiro_e_NarrativaBH['Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro']}).sort_values(by='Email').dropna()
Modulo_Roteiro_e_Narrativa_Polo_Belo_Horizonte_Instituto_BH_Futuro.to_excel("dados_relação_Alunos_Roteiro_e_Narrativa.xlsx", index = False)

Modulo_Programação_Polo_Belo_Horizonte_Instituto_BH_Futuro = pd.DataFrame({
                        'Participante': alunos_modulo_Programação['Participante'],
                        "Email":alunos_modulo_Programação['Email'],
                        'Pontuação': alunos_modulo_Programação['Pontuação pts'].loc[alunos_modulo_Programação['Pontuação pts'] >= 500],
                        'Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro':alunos_modulo_Programação['Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro']}).sort_values(by='Email').dropna()
Modulo_Programação_Polo_Belo_Horizonte_Instituto_BH_Futuro.to_excel("dados_relação_Alunos_programacao.xlsx", index = False)

Modulo_Edição_de_Som_Polo_Belo_Horizonte_Instituto_BH_Futuro = pd.DataFrame({
                        'Participante': alunos_modulo_Edição_de_Som['Participante'],
                        "Email":alunos_modulo_Edição_de_Som['Email'],
                        'Pontuação': alunos_modulo_Edição_de_Som['Pontuação pts'],
                        'Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro':alunos_modulo_Edição_de_Som['Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro']}).sort_values(by='Email').dropna()
Modulo_Edição_de_Som_Polo_Belo_Horizonte_Instituto_BH_Futuro.to_excel("dados_relação_Alunos_Edição_de_Som.xlsx", index = False)

Modulo_Game_Design_Polo_Belo_Horizonte_Instituto_BH_Futuro = pd.DataFrame({
                        'Participante': alunos_modulo_Game_Design['Participante'],
                        "Email":alunos_modulo_Game_Design['Email'],
                        'Pontuação': alunos_modulo_Game_Design['Pontuação pts'].loc[alunos_modulo_Game_Design['Pontuação pts'] >= 500],
                        'Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro':alunos_modulo_Game_Design['Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro']}).sort_values(by='Email').dropna()
Modulo_Game_Design_Polo_Belo_Horizonte_Instituto_BH_Futuro.to_excel("dados_relação_Alunos_gameDesign.xlsx", index = False)

Modulo_Arte_e_Interface_Polo_Belo_Horizonte_Instituto_BH_Futuro = pd.DataFrame({
                        'Participante': alunos_modulo_Arte_e_Interface['Participante'],
                        "Email":alunos_modulo_Arte_e_Interface['Email'],
                        'Pontuação': alunos_modulo_Arte_e_Interface['Pontuação pts'].loc[alunos_modulo_Arte_e_Interface['Pontuação pts'] >= 500],
                        'Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro':alunos_modulo_Arte_e_Interface['Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro']}).sort_values(by='Email').dropna()
Modulo_Arte_e_Interface_Polo_Belo_Horizonte_Instituto_BH_Futuro.to_excel("dados_relação_Alunos_Arte_e_Interface.xlsx", index = False)

Modulo_Protótipo_Polo_Belo_Horizonte_Instituto_BH_Futuro = pd.DataFrame({
                        'Participante': alunos_modulo_Protótipo['Participante'],
                        "Email":alunos_modulo_Protótipo['Email'],
                        'Pontuação': alunos_modulo_Protótipo['Pontuação pts'].loc[alunos_modulo_Protótipo['Pontuação pts'] >= 500],
                        'Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro':alunos_modulo_Protótipo['Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro']}).sort_values(by='Email').dropna()
Modulo_Protótipo_Polo_Belo_Horizonte_Instituto_BH_Futuro.to_excel("dados_relação_Alunos_prototipo.xlsx", index = False)

Modulo_Temporada_Ferias_Polo_Belo_Horizonte_Instituto_BH_Futuro = pd.DataFrame({
                        'Participante': alunos_modulo_Temporada_Ferias['Participante'],
                        "Email":alunos_modulo_Temporada_Ferias['Email'],
                        'Pontuação': alunos_modulo_Temporada_Ferias['Pontuação pts'].loc[alunos_modulo_Temporada_Ferias['Pontuação pts'] >= 1500],
                        'Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro':alunos_modulo_Temporada_Ferias['Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro']}).sort_values(by='Email').dropna()
Modulo_Temporada_Ferias_Polo_Belo_Horizonte_Instituto_BH_Futuro.to_excel("dados_relação_Aluno_Temporada_Ferias.xlsx", index = False)
