# %%
import pandas as pd
import numpy as np
import os

# %%
path = "C:\\Users\\wesle\\VisãoCoop\\03-2023"
# ---------------------------------
sympla = pd.read_excel(os.path.join(path,'NÃO MEXER. Formação Online e Presencial - Lista de Participantes.xlsx'))

# ----------------------------------------
modulo_Alfabetização_Digital = pd.read_excel(os.path.join(path,"Alfabetização Digital - Formação Criar Jogos.xlsx"))
modulo_Cultura_de_Jogos = pd.read_excel(os.path.join(path,"Cultura de Jogos - Formação Criar Jogos.xlsx"))
modulo_Roteiro_e_Narrativa = pd.read_excel(os.path.join(path,"Roteiro e Narrativa - Formação Criar Jogos.xlsx"))
modulo_Programação = pd.read_excel(os.path.join(path,"Programação - Formação Criar Jogos.xlsx"))
modulo_Edição_de_Som = pd.read_excel(os.path.join(path,"Edição de Som - Formação Criar Jogos.xlsx"))
modulo_Game_Design = pd.read_excel(os.path.join(path,"Game Design - Formação Criar Jogos.xlsx"))
modulo_Arte_e_Interface = pd.read_excel(os.path.join(path,"Arte e Interface - Formação Criar Jogos.xlsx"))
modulo_Protótipo = pd.read_excel(os.path.join(path,"Protótipo - Formação Criar Jogos.xlsx"))
modulo_Temporada_Ferias = pd.read_excel(os.path.join(path,"Temporada de Férias - Mercado de Games.xlsx"))
# ----------------------
modulo_Alfabetização_DigitalBH = pd.read_excel(os.path.join(path,"Alfabetização Digital - Polo Belo Horizonte.xlsx"))
modulo_Cultura_de_JogosBH = pd.read_excel(os.path.join(path,"Cultura de Jogos - Polo Belo Horizonte.xlsx"))
modulo_Roteiro_e_NarrativaBH = pd.read_excel(os.path.join(path,"Roteiro e Narrativa - Polo Belo Horizonte.xlsx"))

# %%
### Correção da Tabela

correcao_coluna = sympla.rename(columns=sympla.iloc[0])
alunos_inscritos_sympla_formacaoCriarJogos = correcao_coluna.drop([0, 1]).reset_index(drop=True)

################################
alunos_inscritos_sympla_formacaoCriarJogos.drop(["Data","Tipo de ingresso","Nº","Endereço","Compl.","Bairro","TEL","RG ou CPF","É indicação, filho (a) ou parente de algum dos patrocinadores do projeto?"], axis = 1, inplace = True)

# alunos_inscritos_sympla_formacaoCriarJogos = alunos_inscritos_sympla_formacaoCriarJogos.loc[dados_mentora["Role"] == "mentee"]

# %%
dados_sympla_corrigido = pd.DataFrame({
                        'Nome': alunos_inscritos_sympla_formacaoCriarJogos['Nome'] + " " +alunos_inscritos_sympla_formacaoCriarJogos['Sobrenome'].str.lower(),
                        "Email":alunos_inscritos_sympla_formacaoCriarJogos['Email'].str.lower(),
                        'Formato do curso':alunos_inscritos_sympla_formacaoCriarJogos['Formato do curso'],
                        'Polo Presencial São Gonçalo dos Campos (BA) - Biblioteca Municipal Aníbal Pedreira':alunos_inscritos_sympla_formacaoCriarJogos['Polo Presencial São Gonçalo dos Campos (BA) | Biblioteca Municipal Aníbal Pedreira'],
                        'Polo Presencial São Gonçalo dos Campos (BA) - Colégio Mun. Agripina de L Pedreira':alunos_inscritos_sympla_formacaoCriarJogos['Polo Presencial São Gonçalo dos Campos (BA) | Colégio Mun. Agripina de L Pedreira'],
                        'Polo Presencial Mogi Guaçu (SP) - CEGEP':alunos_inscritos_sympla_formacaoCriarJogos['Polo Presencial Mogi Guaçu (SP) | CEGEP'],
                        'Polo Presencial Camaçari (BA) - UFBA':alunos_inscritos_sympla_formacaoCriarJogos['Polo Presencial Camaçari (BA) | UFBA'],
                        'Polo Presencial Camaçari (BA) - CIAT':alunos_inscritos_sympla_formacaoCriarJogos['Polo Presencial Camaçari (BA) | CIAT']}).sort_values(by='Email')

# %%
dados_sympla_corrigidoBH = pd.DataFrame({
                        'Nome': alunos_inscritos_sympla_formacaoCriarJogos['Nome'] + " " +alunos_inscritos_sympla_formacaoCriarJogos['Sobrenome'].str.lower(),
                        "Email":alunos_inscritos_sympla_formacaoCriarJogos['Email'].str.lower(),
                        'Formato do curso':alunos_inscritos_sympla_formacaoCriarJogos['Formato do curso'],
                        'Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro':alunos_inscritos_sympla_formacaoCriarJogos['Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro']}).sort_values(by='Email')

# %%
modulo_Alfabetização_Digital['Email'] = modulo_Alfabetização_Digital['Email'].str.lower()
modulo_Cultura_de_Jogos['Email'] = modulo_Cultura_de_Jogos['Email'].str.lower()
modulo_Roteiro_e_Narrativa['Email'] = modulo_Roteiro_e_Narrativa['Email'].str.lower()
modulo_Programação['Email'] = modulo_Programação['Email'].str.lower()
modulo_Edição_de_Som['Email'] = modulo_Edição_de_Som['Email'].str.lower()
modulo_Game_Design['Email'] = modulo_Game_Design['Email'].str.lower()
modulo_Arte_e_Interface['Email'] = modulo_Arte_e_Interface['Email'].str.lower()
modulo_Protótipo['Email'] = modulo_Protótipo['Email'].str.lower()
modulo_Temporada_Ferias['Email'] = modulo_Temporada_Ferias['Email'].str.lower()
#------------------------------------
modulo_Alfabetização_DigitalBH['Email'] = modulo_Alfabetização_DigitalBH['Email'].str.lower()
modulo_Cultura_de_JogosBH['Email'] = modulo_Cultura_de_JogosBH['Email'].str.lower()
modulo_Roteiro_e_NarrativaBH['Email'] = modulo_Roteiro_e_NarrativaBH['Email'].str.lower()

# %%
modulo_Alfabetização_Digital.rename(columns= {"Pontuação pts" :"Modulo 1"}, inplace = True)
modulo_Cultura_de_Jogos.rename(columns= {"Pontuação pts" :"Modulo 2"}, inplace = True)
modulo_Roteiro_e_Narrativa.rename(columns= {"Pontuação pts" :"Modulo 3"}, inplace = True)
modulo_Programação.rename(columns= {"Pontuação pts" :"Modulo 4"}, inplace = True)
modulo_Edição_de_Som.rename(columns= {"Pontuação pts" :"Modulo 5"}, inplace = True)
modulo_Game_Design.rename(columns= {"Pontuação pts" :"Modulo 6"}, inplace = True)
modulo_Arte_e_Interface.rename(columns= {"Pontuação pts" :"Modulo 7"}, inplace = True)
modulo_Protótipo.rename(columns= {"Pontuação pts" :"Modulo 8"}, inplace = True)
modulo_Temporada_Ferias.rename(columns= {"Pontuação pts" :"Modulo 9"}, inplace = True)
# POLO BH
modulo_Alfabetização_DigitalBH.rename(columns= {"Pontuação pts" :"Modulo 1"}, inplace = True)
modulo_Cultura_de_JogosBH.rename(columns= {"Pontuação pts" :"Modulo 2"}, inplace = True)
modulo_Roteiro_e_NarrativaBH.rename(columns= {"Pontuação pts" :"Modulo 3"}, inplace = True)

# %%
from functools import reduce

#create a list that contains all your data frames to be merged
data = [dados_sympla_corrigido,modulo_Alfabetização_Digital,modulo_Cultura_de_Jogos,modulo_Roteiro_e_Narrativa,modulo_Programação,modulo_Edição_de_Som,modulo_Game_Design,modulo_Arte_e_Interface,modulo_Protótipo,modulo_Temporada_Ferias]
#necessary to have a common name column to merge all the frames
df = reduce(lambda x,y: pd.merge(x,y, on = "Email", how = "right"), data)

# POLO BH
dataBH = [dados_sympla_corrigidoBH,modulo_Alfabetização_DigitalBH,modulo_Cultura_de_JogosBH,modulo_Roteiro_e_NarrativaBH,modulo_Programação,modulo_Edição_de_Som,modulo_Game_Design,modulo_Arte_e_Interface,modulo_Protótipo,modulo_Temporada_Ferias]
#necessary to have a common name column to merge all the frames
dfBH = reduce(lambda x,y: pd.merge(x,y, on = "Email", how = "right"), dataBH)

# %%
df

# %%
# Extração Polos - Polo Presencial São Gonçalo dos Campos (BA) - Biblioteca Municipal Aníbal Pedreira

Polo_Biblioteca_Municipal_Aníbal_Pedreira = pd.DataFrame({
                        'Nome do aluno':df['Nome'].str.lower(),
                        "Email":df['Email'],
                        'Modulo 1': df['Modulo 1'].loc[df['Modulo 1'] >= 150],
                        'Modulo 2': df['Modulo 2'].loc[df['Modulo 2'] >= 400],
                        'Modulo 3': df['Modulo 3'].loc[df['Modulo 3'] >= 500],
                        'Modulo 4': df['Modulo 4'].loc[df['Modulo 4'] >= 500],
                        'Modulo 5': df['Modulo 5'].loc[df['Modulo 5'] >= 500],
                        'Modulo 6': df['Modulo 6'].loc[df['Modulo 6'] >= 500],
                        'Modulo 7': df['Modulo 7'].loc[df['Modulo 7'] >= 500],
                        'Modulo 8': df['Modulo 8'].loc[df['Modulo 8'] >= 500],
                        'Modulo 9': df['Modulo 9'].loc[df['Modulo 9'] >= 1500],
                        'Polo Presencial São Gonçalo dos Campos (BA) - Biblioteca Municipal Aníbal Pedreira':df['Polo Presencial São Gonçalo dos Campos (BA) - Biblioteca Municipal Aníbal Pedreira']}).sort_values(by='Email').dropna()

# Polo_Biblioteca_Municipal_Aníbal_Pedreira.to_excel("Polo_Biblioteca_Municipal_Aníbal_Pedreira.xlsx", index = False)

Polo_Colégio_Mun_Agripina_de_L_Pedreira = pd.DataFrame({
                        'Nome':df['Nome'].str.lower(),
                        "Email":df['Email'],
                        'Modulo 1': df['Modulo 1'].loc[df['Modulo 1'] >= 150],
                        'Modulo 2': df['Modulo 2'].loc[df['Modulo 2'] >= 400],
                        'Modulo 3': df['Modulo 3'].loc[df['Modulo 3'] >= 500],
                        'Modulo 4': df['Modulo 4'].loc[df['Modulo 4'] >= 500],
                        'Modulo 5': df['Modulo 5'].loc[df['Modulo 5'] >= 500],
                        'Modulo 6': df['Modulo 6'].loc[df['Modulo 6'] >= 500],
                        'Modulo 7': df['Modulo 7'].loc[df['Modulo 7'] >= 500],
                        'Modulo 8': df['Modulo 8'].loc[df['Modulo 8'] >= 500],
                        'Modulo 9': df['Modulo 9'].loc[df['Modulo 9'] >= 1500],
                        'Polo Presencial São Gonçalo dos Campos (BA) - Colégio Mun. Agripina de L Pedreira':df['Polo Presencial São Gonçalo dos Campos (BA) - Colégio Mun. Agripina de L Pedreira']}).sort_values(by='Email').dropna()

# Polo_Colégio_Mun_Agripina_de_L_Pedreira.to_excel("Polo_Colégio_Mun_Agripina_de_L_Pedreira.xlsx", index = False)

Polo_Presencial_Camaçari_UFBA = pd.DataFrame({
                        'Nome':df['Nome'].str.lower(),
                        "Email":df['Email'],
                        'Modulo 1': df['Modulo 1'].loc[df['Modulo 1'] >= 150],
                        'Modulo 2': df['Modulo 2'].loc[df['Modulo 2'] >= 400],
                        'Modulo 3': df['Modulo 3'].loc[df['Modulo 3'] >= 500],
                        'Modulo 4': df['Modulo 4'].loc[df['Modulo 4'] >= 500],
                        'Modulo 5': df['Modulo 5'].loc[df['Modulo 5'] >= 500],
                        'Modulo 6': df['Modulo 6'].loc[df['Modulo 6'] >= 500],
                        'Modulo 7': df['Modulo 7'].loc[df['Modulo 7'] >= 500],
                        'Modulo 8': df['Modulo 8'].loc[df['Modulo 8'] >= 500],
                        'Modulo 9': df['Modulo 9'].loc[df['Modulo 9'] >= 1500],
                        'Polo Presencial Camaçari (BA) - UFBA':df['Polo Presencial Camaçari (BA) - UFBA']}).sort_values(by='Email').dropna()

Polo_Presencial_Camaçari_UFBA.to_excel("Polo_Presencial_Camaçari_UFBA.xlsx", index = False)

Polo_Presencial_Camaçari_CIAT = pd.DataFrame({
                        'Nome':df['Nome'].str.lower(),
                        "Email":df['Email'],
                        'Modulo 1': df['Modulo 1'].loc[df['Modulo 1'] >= 150],
                        'Modulo 2': df['Modulo 2'].loc[df['Modulo 2'] >= 400],
                        'Modulo 3': df['Modulo 3'].loc[df['Modulo 3'] >= 500],
                        'Modulo 4': df['Modulo 4'].loc[df['Modulo 4'] >= 500],
                        'Modulo 5': df['Modulo 5'].loc[df['Modulo 5'] >= 500],
                        'Modulo 6': df['Modulo 6'].loc[df['Modulo 6'] >= 500],
                        'Modulo 7': df['Modulo 7'].loc[df['Modulo 7'] >= 500],
                        'Modulo 8': df['Modulo 8'].loc[df['Modulo 8'] >= 500],
                        'Modulo 9': df['Modulo 9'].loc[df['Modulo 9'] >= 1500],
                        'Polo Presencial Camaçari (BA) - CIAT':df['Polo Presencial Camaçari (BA) - CIAT']}).sort_values(by='Email').dropna()

# Polo_Presencial_Camaçari_CIAT.to_excel("Polo_Presencial_Camaçari_CIAT.xlsx", index = False)

Polo_Mogi_Guaçu_CEGEP = pd.DataFrame({
                        'Nome':df['Nome'].str.lower(),
                        "Email":df['Email'],
                        'Modulo 1': df['Modulo 1'].loc[df['Modulo 1'] >= 150],
                        'Modulo 2': df['Modulo 2'].loc[df['Modulo 2'] >= 400],
                        'Modulo 3': df['Modulo 3'].loc[df['Modulo 3'] >= 500],
                        'Modulo 4': df['Modulo 4'].loc[df['Modulo 4'] >= 500],
                        'Modulo 5': df['Modulo 5'].loc[df['Modulo 5'] >= 500],
                        'Modulo 6': df['Modulo 6'].loc[df['Modulo 6'] >= 500],
                        'Modulo 7': df['Modulo 7'].loc[df['Modulo 7'] >= 500],
                        'Modulo 8': df['Modulo 8'].loc[df['Modulo 8'] >= 500],
                        'Modulo 9': df['Modulo 9'].loc[df['Modulo 9'] >= 1500],
                        'Polo Presencial Mogi Guaçu (SP) - CEGEP':df['Polo Presencial Mogi Guaçu (SP) - CEGEP']}).sort_values(by='Email').dropna()

# Polo_Mogi_Guaçu_CEGEP.to_excel("Polo_Mogi_Guaçu_CEGEP.xlsx", index = False)

Polo_Belo_Horizonte_Instituto_BH_Futuro = pd.DataFrame({
                        'Nome':dfBH['Nome'].str.lower(),
                        "Email":dfBH['Email'],
                        'Modulo 1': dfBH['Modulo 1'].loc[dfBH['Modulo 1'] >= 150],
                        'Modulo 2': dfBH['Modulo 2'].loc[dfBH['Modulo 2'] >= 400],
                        'Modulo 3': dfBH['Modulo 3'].loc[dfBH['Modulo 3'] >= 500],
                        'Modulo 4': dfBH['Modulo 4'].loc[dfBH['Modulo 4'] >= 500],
                        'Modulo 5': dfBH['Modulo 5'].loc[dfBH['Modulo 5'] >= 500],
                        'Modulo 6': dfBH['Modulo 6'].loc[dfBH['Modulo 6'] >= 500],
                        'Modulo 7': dfBH['Modulo 7'].loc[dfBH['Modulo 7'] >= 500],
                        'Modulo 8': dfBH['Modulo 8'].loc[dfBH['Modulo 8'] >= 500],
                        'Modulo 9': dfBH['Modulo 9'].loc[dfBH['Modulo 9'] >= 1500],
                        'Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro':dfBH['Polo Presencial Belo Horizonte (MG) - Instituto BH Futuro']}).sort_values(by='Email').dropna()

# Polo_Belo_Horizonte_Instituto_BH_Futuro.to_excel("Polo_Belo_Horizonte_Instituto_BH_Futuro.xlsx", index = False)
